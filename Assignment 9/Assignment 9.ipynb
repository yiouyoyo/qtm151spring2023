# %% [markdown]
# # Assignment 9

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your name below

# %%
print("Annie He")
# Out:
# Annie He

# %% [markdown]
# <font size = "5">
#
# Import the "pandas", "sqlalchemy" and "URL" libraries <br>
# (See Lecture 20)

# %%
# Write your answer here:
import pandas as pd
import psycopg2
import sqlalchemy as sa
from   sqlalchemy.engine import URL
from   sqlalchemy import text

# %% [markdown]
# <font size = "5">
#
# Establish a connection to the SQL server <br>
# from Python as in Lecture 20 using <br>
# ```URL()``` and ```create_engine()```

# %%
# Write your own code
url_server = URL.create(
    "postgresql",
    host = 'localhost',
    database = 'postgres',
    username = 'postgres',
    port = 5432,
    password  = '12345')

con = sa.create_engine(url_server).connect()

# %% [markdown]
# <font size = "5">
#
# In this homework, you will repeat the exercises in <br>
# Assignment 8, this time accessing SQL indirectly <br>
# from Python
#
# <font size = "3">
#
# - For (a)-(e) read the section <br>
# on "Escape Characters" carefully and how to write <br>
# strings in multiple lines
# - Remember that there is a special syntax for <br>
# column names that have capital letters

# %% [markdown]
# <font size = "5">
#
# (a) Import "lap_times.csv" and "drivers.csv"
#
# <font size = "3">
#
# - Import the data using ```pd.read_csv()```
# - Upload to the server using  ```.to_sql()```

# %%
# Write your own code
lap_times= pd.read_csv("/Users/anniehe/Documents/GitHub/qtm151spring2023/Assignment 9/data_raw/lap_times.csv")
drivers= pd.read_csv("/Users/anniehe/Documents/GitHub/qtm151spring2023/Assignment 9/data_raw/drivers.csv")

lap_times.to_sql('laps_sql',con, if_exists='replace')
drivers.to_sql('drivers_sql',con, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/mv/kzmggzbd4p9flg3xbm__wb780000gn/T/ipykernel_97117/1185371532.py in <module>
#       3 drivers= pd.read_csv("/Users/anniehe/Documents/GitHub/qtm151spring2023/Assignment 9/data_raw/drivers.csv")
#       4
# ----> 5 lap_times.to_sql('laps_sql',con, if_exists='replace')
#       6 drivers.to_sql('drivers_sql',con, if_exists='replace')
#       7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1740         )
#    1741
# -> 1742         total_inserted = sql_engine.insert_records(
#    1743             table=table,
#    1744             con=self.connectable,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1323
#    1324         try:
# -> 1325             return table.insert(chunksize=chunksize, method=method)
#    1326         except exc.SQLAlchemyError as err:
#    1327             # GH34431
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     949
#     950                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 951                 num_inserted = exec_insert(conn, keys, chunk_iter)
#     952                 # GH 46891
#     953                 if is_integer(num_inserted):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     856         """
#     857         data = [dict(zip(keys, row)) for row in data_iter]
# --> 858         result = conn.execute(self.table.insert(), data)
#     859         return result.rowcount
#     860
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1304             )
#    1305         else:
# -> 1306             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1307
#    1308     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     330     ):
#     331         if _force or self.supports_execution:
# --> 332             return connection._execute_clauseelement(
#     333                 self, multiparams, params, execution_options
#     334             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1496             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497         )
# -> 1498         ret = self._execute_context(
#    1499             dialect,
#    1500             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1860
#    1861         except BaseException as e:
# -> 1862             self._handle_dbapi_exception(
#    1863                 e, statement, parameters, cursor, context
#    1864             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2045                 )
#    2046             else:
# -> 2047                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2048
#    2049         finally:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                             break
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_executemany(
#    1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     951                 kwargs = {}
#     952             xtras = self._psycopg2_extras()
# --> 953             context._psycopg2_fetched_rows = xtras.execute_values(
#     954                 cursor,
#     955                 statement,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1294         parts = pre[:]
#    1295         for args in page:
# -> 1296             parts.append(cur.mogrify(template, args))
#    1297             parts.append(b',')
#    1298         parts[-1:] = post
#
# KeyboardInterrupt:

# %% [markdown]
# <font size = "5">
#
# (b) Subset and sort
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Use ```WHERE``` to get a subset of "drivers" with
# ```nationality = 'American'```
# - Chain this with ```ORDER BY surname ASC``` to sort in <br>
# ascending order
#
# HINT: Use single quotes inside a string as in Lecture 20

# %%
# Write your own code
pd.read_sql(text("SELECT * \
                    FROM drivers_sql \
                    WHERE nationality = 'American'\
                    ORDER BY surname ASC;"),con)
# Out:
#      index  driverId       driverRef number code forename     surname  \
# 0      796       796            ader     \N   \N     Walt        Ader
# 1      615       615      agabashian     \N   \N     Fred  Agabashian
# 2      591       591    george_amick     \N   \N   George       Amick
# 3      517       517           amick     \N   \N      Red       Amick
# 4      120       121        andretti     \N   \N  Michael    Andretti
# ..     ...       ...             ...    ...  ...      ...         ...
# 153    448       449            ward     \N   \N   Rodger        Ward
# 154    677       677            webb     \N   \N   Travis        Webb
# 155    530       530          weiler     \N   \N    Wayne      Weiler
# 156    563       563          weyant     \N   \N    Chuck      Weyant
# 157    539       539  dempsey_wilson     \N   \N  Dempsey      Wilson
#
#             dob nationality                                            url
# 0    1913-12-15    American         http://en.wikipedia.org/wiki/Walt_Ader
# 1    1913-08-21    American   http://en.wikipedia.org/wiki/Fred_Agabashian
# 2    1924-10-24    American      http://en.wikipedia.org/wiki/George_Amick
# 3    1929-01-19    American         http://en.wikipedia.org/wiki/Red_Amick
# 4    1962-10-05    American  http://en.wikipedia.org/wiki/Michael_Andretti
# ..          ...         ...                                            ...
# 153  1921-01-10    American       http://en.wikipedia.org/wiki/Rodger_Ward
# 154  1910-10-08    American       http://en.wikipedia.org/wiki/Travis_Webb
# 155  1934-12-09    American      http://en.wikipedia.org/wiki/Wayne_Weiler
# 156  1923-04-03    American      http://en.wikipedia.org/wiki/Chuck_Weyant
# 157  1927-03-11    American    http://en.wikipedia.org/wiki/Dempsey_Wilson
#
# [158 rows x 10 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Count unique values
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Count the number of unique "driverId" using ```COUNT(DISTINCT ...)``` <br>
# from the dataset "drivers"
#
# HINT: Include \\"driverId\\" in double quotations with an <br>
# escape character (see Lecture 20 for details) since <br>
# it has a mix of upper and lower case letters

# %%
# Write your own code
pd.read_sql(text("SELECT \
                COUNT(DISTINCT \"driverId\") AS num_driver_id \
                FROM drivers_sql"),con)
# Out:
#    num_driver_id
# 0            857

# %% [markdown]
# <font size = "5">
#
# (d) Groupby + Aggregate + Sort
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Obtain the average of "milliseconds" by "driverId" using ```GROUP BY```
# - User ```ORDER BY ``` to sort on the average of milliseconds
#
# HINT: Include \\"driverId\\" in double quotations with an <br>
# escape character (see Lecture 20 for details) since <br>
# it has a mix of upper and lower case letters

# %%
# Write your own code
pd.read_sql(text("SELECT AVG(milliseconds) as AVG_seconds \
                             FROM laps_sql \
                             GROUP BY \"driverId\" \
                             ORDER BY AVG_seconds ASC;"),con)
# Out:
#        avg_seconds
# 0     63319.402299
# 1     80792.571429
# 2     82907.903226
# 3     86875.075472
# 4     86976.960138
# ..             ...
# 132  108922.468668
# 133  110940.722915
# 134  114121.786207
# 135  129985.000000
# 136  235988.692308
#
# [137 rows x 1 columns]

# %% [markdown]
# <font size = "5">
#
# (e) Merge two tables
#
# <font size = "3">
#
# - In this exercise use the function ```.read_sql()```
# - Merge the tables "lap_times" (primary) and "drivers" (secondary) <br>
# on "driverId" using ```LEFT JOIN``` on "driverId".
#
# HINT: Include \\"driverId\\" in double quotations with an <br>
# escape character (see Lecture 20 for details) since <br>
# it has a mix of upper and lower case letters

# %%
pd.read_sql(text("SELECT * \
                 FROM lap_times \
                 LEFT JOIN drivers \
                 ON lap_times.\"driverId\" = drivers.\"driverId\" ;"),con)
# Out:
# Empty DataFrame
# Columns: [raceId, driverId, lap, position, time, milliseconds, driverId, driverRef, number, code, forename, surname, dob, nationality, url]
# Index: []

# %%
# Write your own code
pd.read_sql(text("SELECT * \
                FROM laps_sql \
                LEFT JOIN drivers_sql \
                ON laps_sql.\"driverId\" = drivers_sql.\"driverId\" ;"),con)
# Out:
# Empty DataFrame
# Columns: [index, raceId, driverId, lap, position, time, milliseconds, index, driverId, driverRef, number, code, forename, surname, dob, nationality, url]
# Index: []
